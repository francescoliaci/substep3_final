# %% [markdown]
# # Substep 3 — Task Graph Encoding + Step Matching (EgoVLP)
#
# This notebook:
# 1. Installs EgoVLP explicitly
# 2. Loads project data from Google Drive
# 3. Runs `sub3.py` to generate realized task graphs

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("Torch version:", torch.__version__)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls /content/drive/MyDrive/AMLproject

# %%
# clone repo here
# !git clone https://github.com/francescoliaci/substep3

# %%
# clone egoVLP repo here
# !git clone https://github.com/francescoliaci/EgoVLP-main

# %%
# !pip install numpy scipy pandas tqdm networkx

# %%
# %cd /content/substep3

# %%
# !pip install av
# !pip install decord
# !pip install ffmpeg

# %%
# !python sub3.py
